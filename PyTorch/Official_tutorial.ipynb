# %%
import torch

# %%
import torchvision
from torch.autograd import Variable

# %% [markdown]
# # Pytorch #
# - Tensorflow와 비교되는 가장 큰 장점
#     - Graph의 Dynamic한 설정 ( <-> Tensorflow는 Graph를 설정한 후 Session을 돌려 계산해야하므로, 그래프가 수시로 바뀌는 경우에는 적합하지 않다
# - ## Pytorch 의 특징 ##
#     - numpy와 비슷하지만 GPU에서 동작하는 n차원 Tensor
#         - 개념상 numpy와 완전히 동일함.
#     - 뉴럴넷의 자동 빌드와 학습
# - ## Pytorch 의 컨셉 ##
#     - ### Autograd ###
#     ~~~~
#     from torch.autograd import Variable
#     ~~~~
#         -Backward Differentiation의 자동화.
#         -Autograd를 사용하면 network에의 forward pass는 computational graph를 정의하는데, 이 그래프의 각 node가 Tensor, Edge가 input으로부터 output tensor를 만드는 function이 된다.
#
#
#         -Tensor를 Variable 객체로 Warp한다
#         -Variable은 그래프의 Node가 된다.
#         -만일 **x** 가 **Variable** 이라면, **x.data** 는 **Tensor** 가 된다.

# %% [markdown]
# # nn module #
# - 텐서플로우에서의 Keras와 같이, 뉴럴넷을 더욱 추상화하여 제공하는 인터페이스.
# - ** nn package ** 는 몇 개의 module을 정의하는데, 각 모듈은 대략 한 개씩의 Layer를 의미한다.
# > model = torch.nn.Sequential(
# >    torch.nn.Linear(D_in, H),
# >    torch.nn.ReLU(),
# >    torch.nn.Linear(H, D_out),
# )
#
# - 한 개의 모듈은 Input, Output, Hidden state(학습가능한 Variable 값)를 갖는다.
# - ** nn package ** 는 여러 가지 쓸모있는 loss function도 제공한다.
#
#
# ## optim module ##
# - nn module을 활용하여 우리는 .data를 Learnable parameter를 갖고 있는 Varaible로 변환시킴으로써 Layer의 weight를 학습하였다.
# - SGD Algorithm과 같이 간단한 최적화 알고리즘은 별 문제가 안되지만, 우리는 실제 상황에서 **Adam, AdaGrad, RMSProp** 등과 같은 복잡하고 어려운 최적화 기법을 사용해야한다.
# - ** optim ** package는 이러한 알고리즘을 추상화한 모듈을 제공한다.
# - nn module로 model을 define하고, optim module로 이러한 model을 최적화한다.

# %%
# CPU Run
dtype = torch.FloatTensor

# GPU Run
# dtype = torch.cuda.FloatTensor

# N : Batch size, D_in, D_out : I/O dimension
# H ; Hidden dimension 
N, D_in, H, D_out = 64, 1000, 100, 10

# %%
from collections import OrderedDict
class MyModel(torch.nn.Module):
    def __init__(self, D_in, H, D_out):
        super(MyModel, self).__init__()
        self.net = torch.nn.Sequential(OrderedDict(
        [
            ('layer1', torch.nn.Linear(D_in, H)),
            ('ReLU 1', torch.nn.ReLU()),
            ('layer2', torch.nn.Linear(H,D_out))
        ])
        )
    def forward(self, x):
        return self.net(x)

# %%
x = Variable(torch.randn(N, D_in).type(dtype))
y = Variable(torch.randn(N, D_out).type(dtype), requires_grad=False)

# %%
#w1 = Variable(torch.randn(D_in, H).type(dtype), requires_grad=True)
#w2 = Variable(torch.randn(H, D_out).type(dtype), requires_grad=True)
mymodel = MyModel(D_in, H, D_out)

# %%
learning_rate = 1e-4
criterion = torch.nn.MSELoss(size_average=False)
optimizer = torch.optim.SGD(mymodel.parameters(), lr=learning_rate)

# %%
for step in range(500):
    y_pred = mymodel(x)
    loss = criterion(y_pred, y)
    print(step, loss[0])
    
    # Zero gradient 
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()
# Out:
# 0 Variable containing:
#  660.8212
# [torch.FloatTensor of size 1]
#
# 1 Variable containing:
#  609.5247
# [torch.FloatTensor of size 1]
#
# 2 Variable containing:
#  565.1561
# [torch.FloatTensor of size 1]
#
# 3 Variable containing:
#  526.4247
# [torch.FloatTensor of size 1]
#
# 4 Variable containing:
#  492.2836
# [torch.FloatTensor of size 1]
#
# 5 Variable containing:
#  461.7029
# [torch.FloatTensor of size 1]
#
# 6 Variable containing:
#  434.0302
# [torch.FloatTensor of size 1]
#
# 7 Variable containing:
#  408.8206
# [torch.FloatTensor of size 1]
#
# 8 Variable containing:
#  385.5237
# [torch.FloatTensor of size 1]
#
# 9 Variable containing:
#  363.9130
# [torch.FloatTensor of size 1]
#
# 10 Variable containing:
#  343.7212
# [torch.FloatTensor of size 1]
#
# 11 Variable containing:
#  324.7186
# [torch.FloatTensor of size 1]
#
# 12 Variable containing:
#  306.8974
# [torch.FloatTensor of size 1]
#
# 13 Variable containing:
#  290.0514
# [torch.FloatTensor of size 1]
#
# 14 Variable containing:
#  274.1606
# [torch.FloatTensor of size 1]
#
# 15 Variable containing:
#  259.0939
# [torch.FloatTensor of size 1]
#
# 16 Variable containing:
#  244.8080
# [torch.FloatTensor of size 1]
#
# 17 Variable containing:
#  231.2199
# [torch.FloatTensor of size 1]
#
# 18 Variable containing:
#  218.3642
# [torch.FloatTensor of size 1]
#
# 19 Variable containing:
#  206.1811
# [torch.FloatTensor of size 1]
#
# 20 Variable containing:
#  194.5851
# [torch.FloatTensor of size 1]
#
# 21 Variable containing:
#  183.5480
# [torch.FloatTensor of size 1]
#
# 22 Variable containing:
#  173.0886
# [torch.FloatTensor of size 1]
#
# 23 Variable containing:
#  163.1712
# [torch.FloatTensor of size 1]
#
# 24 Variable containing:
#  153.7612
# [torch.FloatTensor of size 1]
#
# 25 Variable containing:
#  144.8459
# [torch.FloatTensor of size 1]
#
# 26 Variable containing:
#  136.4101
# [torch.FloatTensor of size 1]
#
# 27 Variable containing:
#  128.4245
# [torch.FloatTensor of size 1]
#
# 28 Variable containing:
#  120.8589
# [torch.FloatTensor of size 1]
#
# 29 Variable containing:
#  113.7071
# [torch.FloatTensor of size 1]
#
# 30 Variable containing:
#  106.9555
# [torch.FloatTensor of size 1]
#
# 31 Variable containing:
#  100.5650
# [torch.FloatTensor of size 1]
#
# 32 Variable containing:
#  94.5206
# [torch.FloatTensor of size 1]
#
# 33 Variable containing:
#  88.8285
# [torch.FloatTensor of size 1]
#
# 34 Variable containing:
#  83.4798
# [torch.FloatTensor of size 1]
#
# 35 Variable containing:
#  78.4456
# [torch.FloatTensor of size 1]
#
# 36 Variable containing:
#  73.7104
# [torch.FloatTensor of size 1]
#
# 37 Variable containing:
#  69.2562
# [torch.FloatTensor of size 1]
#
# 38 Variable containing:
#  65.0658
# [torch.FloatTensor of size 1]
#
# 39 Variable containing:
#  61.1346
# [torch.FloatTensor of size 1]
#
# 40 Variable containing:
#  57.4380
# [torch.FloatTensor of size 1]
#
# 41 Variable containing:
#  53.9671
# [torch.FloatTensor of size 1]
#
# 42 Variable containing:
#  50.7142
# [torch.FloatTensor of size 1]
#
# 43 Variable containing:
#  47.6687
# [torch.FloatTensor of size 1]
#
# 44 Variable containing:
#  44.8121
# [torch.FloatTensor of size 1]
#
# 45 Variable containing:
#  42.1286
# [torch.FloatTensor of size 1]
#
# 46 Variable containing:
#  39.6110
# [torch.FloatTensor of size 1]
#
# 47 Variable containing:
#  37.2502
# [torch.FloatTensor of size 1]
#
# 48 Variable containing:
#  35.0365
# [torch.FloatTensor of size 1]
#
# 49 Variable containing:
#  32.9610
# [torch.FloatTensor of size 1]
#
# 50 Variable containing:
#  31.0122
# [torch.FloatTensor of size 1]
#
# 51 Variable containing:
#  29.1843
# [torch.FloatTensor of size 1]
#
# 52 Variable containing:
#  27.4702
# [torch.FloatTensor of size 1]
#
# 53 Variable containing:
#  25.8615
# [torch.FloatTensor of size 1]
#
# 54 Variable containing:
#  24.3506
# [torch.FloatTensor of size 1]
#
# 55 Variable containing:
#  22.9357
# [torch.FloatTensor of size 1]
#
# 56 Variable containing:
#  21.6074
# [torch.FloatTensor of size 1]
#
# 57 Variable containing:
#  20.3624
# [torch.FloatTensor of size 1]
#
# 58 Variable containing:
#  19.1927
# [torch.FloatTensor of size 1]
#
# 59 Variable containing:
#  18.0943
# [torch.FloatTensor of size 1]
#
# 60 Variable containing:
#  17.0626
# [torch.FloatTensor of size 1]
#
# 61 Variable containing:
#  16.0956
# [torch.FloatTensor of size 1]
#
# 62 Variable containing:
#  15.1843
# [torch.FloatTensor of size 1]
#
# 63 Variable containing:
#  14.3295
# [torch.FloatTensor of size 1]
#
# 64 Variable containing:
#  13.5253
# [torch.FloatTensor of size 1]
#
# 65 Variable containing:
#  12.7703
# [torch.FloatTensor of size 1]
#
# 66 Variable containing:
#  12.0588
# [torch.FloatTensor of size 1]
#
# 67 Variable containing:
#  11.3887
# [torch.FloatTensor of size 1]
#
# 68 Variable containing:
#  10.7577
# [torch.FloatTensor of size 1]
#
# 69 Variable containing:
#  10.1641
# [torch.FloatTensor of size 1]
#
# 70 Variable containing:
#  9.6061
# [torch.FloatTensor of size 1]
#
# 71 Variable containing:
#  9.0803
# [torch.FloatTensor of size 1]
#
# 72 Variable containing:
#  8.5859
# [torch.FloatTensor of size 1]
#
# 73 Variable containing:
#  8.1203
# [torch.FloatTensor of size 1]
#
# 74 Variable containing:
#  7.6813
# [torch.FloatTensor of size 1]
#
# 75 Variable containing:
#  7.2677
# [torch.FloatTensor of size 1]
#
# 76 Variable containing:
#  6.8779
# [torch.FloatTensor of size 1]
#
# 77 Variable containing:
#  6.5110
# [torch.FloatTensor of size 1]
#
# 78 Variable containing:
#  6.1640
# [torch.FloatTensor of size 1]
#
# 79 Variable containing:
#  5.8369
# [torch.FloatTensor of size 1]
#
# 80 Variable containing:
#  5.5279
# [torch.FloatTensor of size 1]
#
# 81 Variable containing:
#  5.2364
# [torch.FloatTensor of size 1]
#
# 82 Variable containing:
#  4.9611
# [torch.FloatTensor of size 1]
#
# 83 Variable containing:
#  4.7012
# [torch.FloatTensor of size 1]
#
# 84 Variable containing:
#  4.4559
# [torch.FloatTensor of size 1]
#
# 85 Variable containing:
#  4.2246
# [torch.FloatTensor of size 1]
#
# 86 Variable containing:
#  4.0060
# [torch.FloatTensor of size 1]
#
# 87 Variable containing:
#  3.7983
# [torch.FloatTensor of size 1]
#
# 88 Variable containing:
#  3.6022
# [torch.FloatTensor of size 1]
#
# 89 Variable containing:
#  3.4168
# [torch.FloatTensor of size 1]
#
# 90 Variable containing:
#  3.2416
# [torch.FloatTensor of size 1]
#
# 91 Variable containing:
#  3.0758
# [torch.FloatTensor of size 1]
#
# 92 Variable containing:
#  2.9188
# [torch.FloatTensor of size 1]
#
# 93 Variable containing:
#  2.7703
# [torch.FloatTensor of size 1]
#
# 94 Variable containing:
#  2.6292
# [torch.FloatTensor of size 1]
#
# 95 Variable containing:
#  2.4958
# [torch.FloatTensor of size 1]
#
# 96 Variable containing:
#  2.3695
# [torch.FloatTensor of size 1]
#
# 97 Variable containing:
#  2.2501
# [torch.FloatTensor of size 1]
#
# 98 Variable containing:
#  2.1371
# [torch.FloatTensor of size 1]
#
# 99 Variable containing:
#  2.0301
# [torch.FloatTensor of size 1]
#
# 100 Variable containing:
#  1.9288
# [torch.FloatTensor of size 1]
#
# 101 Variable containing:
#  1.8325
# [torch.FloatTensor of size 1]
#
# 102 Variable containing:
#  1.7413
# [torch.FloatTensor of size 1]
#
# 103 Variable containing:
#  1.6549
# [torch.FloatTensor of size 1]
#
# 104 Variable containing:
#  1.5732
# [torch.FloatTensor of size 1]
#
# 105 Variable containing:
#  1.4958
# [torch.FloatTensor of size 1]
#
# 106 Variable containing:
#  1.4224
# [torch.FloatTensor of size 1]
#
# 107 Variable containing:
#  1.3528
# [torch.FloatTensor of size 1]
#
# 108 Variable containing:
#  1.2868
# [torch.FloatTensor of size 1]
#
# 109 Variable containing:
#  1.2243
# [torch.FloatTensor of size 1]
#
# 110 Variable containing:
#  1.1649
# [torch.FloatTensor of size 1]
#
# 111 Variable containing:
#  1.1086
# [torch.FloatTensor of size 1]
#
# 112 Variable containing:
#  1.0552
# [torch.FloatTensor of size 1]
#
# 113 Variable containing:
#  1.0046
# [torch.FloatTensor of size 1]
#
# 114 Variable containing:
#  0.9564
# [torch.FloatTensor of size 1]
#
# 115 Variable containing:
#  0.9107
# [torch.FloatTensor of size 1]
#
# 116 Variable containing:
#  0.8672
# [torch.FloatTensor of size 1]
#
# 117 Variable containing:
#  0.8259
# [torch.FloatTensor of size 1]
#
# 118 Variable containing:
#  0.7867
# [torch.FloatTensor of size 1]
#
# 119 Variable containing:
#  0.7495
# [torch.FloatTensor of size 1]
#
# 120 Variable containing:
#  0.7142
# [torch.FloatTensor of size 1]
#
# 121 Variable containing:
#  0.6807
# [torch.FloatTensor of size 1]
#
# 122 Variable containing:
#  0.6488
# [torch.FloatTensor of size 1]
#
# 123 Variable containing:
#  0.6186
# [torch.FloatTensor of size 1]
#
# 124 Variable containing:
#  0.5898
# [torch.FloatTensor of size 1]
#
# 125 Variable containing:
#  0.5625
# [torch.FloatTensor of size 1]
#
# 126 Variable containing:
#  0.5365
# [torch.FloatTensor of size 1]
#
# 127 Variable containing:
#  0.5118
# [torch.FloatTensor of size 1]
#
# 128 Variable containing:
#  0.4883
# [torch.FloatTensor of size 1]
#
# 129 Variable containing:
#  0.4660
# [torch.FloatTensor of size 1]
#
# 130 Variable containing:
#  0.4447
# [torch.FloatTensor of size 1]
#
# 131 Variable containing:
#  0.4246
# [torch.FloatTensor of size 1]
#
# 132 Variable containing:
#  0.4053
# [torch.FloatTensor of size 1]
#
# 133 Variable containing:
#  0.3870
# [torch.FloatTensor of size 1]
#
# 134 Variable containing:
#  0.3696
# [torch.FloatTensor of size 1]
#
# 135 Variable containing:
#  0.3530
# [torch.FloatTensor of size 1]
#
# 136 Variable containing:
#  0.3372
# [torch.FloatTensor of size 1]
#
# 137 Variable containing:
#  0.3221
# [torch.FloatTensor of size 1]
#
# 138 Variable containing:
#  0.3078
# [torch.FloatTensor of size 1]
#
# 139 Variable containing:
#  0.2941
# [torch.FloatTensor of size 1]
#
# 140 Variable containing:
#  0.2811
# [torch.FloatTensor of size 1]
#
# 141 Variable containing:
#  0.2687
# [torch.FloatTensor of size 1]
#
# 142 Variable containing:
#  0.2569
# [torch.FloatTensor of size 1]
#
# 143 Variable containing:
#  0.2456
# [torch.FloatTensor of size 1]
#
# 144 Variable containing:
#  0.2349
# [torch.FloatTensor of size 1]
#
# 145 Variable containing:
#  0.2247
# [torch.FloatTensor of size 1]
#
# 146 Variable containing:
#  0.2149
# [torch.FloatTensor of size 1]
# 147 Variable containing:
#  0.2056
# [torch.FloatTensor of size 1]
#
# 148 Variable containing:
#  0.1967
# [torch.FloatTensor of size 1]
#
# 149 Variable containing:
#  0.1883
# [torch.FloatTensor of size 1]
#
# 150 Variable containing:
#  0.1802
# [torch.FloatTensor of size 1]
#
# 151 Variable containing:
#  0.1725
# [torch.FloatTensor of size 1]
#
# 152 Variable containing:
#  0.1651
# [torch.FloatTensor of size 1]
#
# 153 Variable containing:
#  0.1581
# [torch.FloatTensor of size 1]
#
# 154 Variable containing:
#  0.1514
# [torch.FloatTensor of size 1]
#
# 155 Variable containing:
#  0.1450
# [torch.FloatTensor of size 1]
#
# 156 Variable containing:
#  0.1389
# [torch.FloatTensor of size 1]
#
# 157 Variable containing:
#  0.1331
# [torch.FloatTensor of size 1]
#
# 158 Variable containing:
#  0.1275
# [torch.FloatTensor of size 1]
#
# 159 Variable containing:
#  0.1222
# [torch.FloatTensor of size 1]
#
# 160 Variable containing:
#  0.1171
# [torch.FloatTensor of size 1]
#
# 161 Variable containing:
#  0.1123
# [torch.FloatTensor of size 1]
#
# 162 Variable containing:
#  0.1076
# [torch.FloatTensor of size 1]
#
# 163 Variable containing:
#  0.1032
# [torch.FloatTensor of size 1]
#
# 164 Variable containing:
# 1.00000e-02 *
#   9.8934
# [torch.FloatTensor of size 1]
#
# 165 Variable containing:
# 1.00000e-02 *
#   9.4878
# [torch.FloatTensor of size 1]
#
# 166 Variable containing:
# 1.00000e-02 *
#   9.0999
# [torch.FloatTensor of size 1]
#
# 167 Variable containing:
# 1.00000e-02 *
#   8.7290
# [torch.FloatTensor of size 1]
#
# 168 Variable containing:
# 1.00000e-02 *
#   8.3742
# [torch.FloatTensor of size 1]
#
# 169 Variable containing:
# 1.00000e-02 *
#   8.0347
# [torch.FloatTensor of size 1]
#
# 170 Variable containing:
# 1.00000e-02 *
#   7.7098
# [torch.FloatTensor of size 1]
#
# 171 Variable containing:
# 1.00000e-02 *
#   7.3989
# [torch.FloatTensor of size 1]
#
# 172 Variable containing:
# 1.00000e-02 *
#   7.1012
# [torch.FloatTensor of size 1]
#
# 173 Variable containing:
# 1.00000e-02 *
#   6.8162
# [torch.FloatTensor of size 1]
#
# 174 Variable containing:
# 1.00000e-02 *
#   6.5434
# [torch.FloatTensor of size 1]
#
# 175 Variable containing:
# 1.00000e-02 *
#   6.2821
# [torch.FloatTensor of size 1]
#
# 176 Variable containing:
# 1.00000e-02 *
#   6.0322
# [torch.FloatTensor of size 1]
#
# 177 Variable containing:
# 1.00000e-02 *
#   5.7924
# [torch.FloatTensor of size 1]
#
# 178 Variable containing:
# 1.00000e-02 *
#   5.5629
# [torch.FloatTensor of size 1]
#
# 179 Variable containing:
# 1.00000e-02 *
#   5.3424
# [torch.FloatTensor of size 1]
#
# 180 Variable containing:
# 1.00000e-02 *
#   5.1312
# [torch.FloatTensor of size 1]
#
# 181 Variable containing:
# 1.00000e-02 *
#   4.9290
# [torch.FloatTensor of size 1]
#
# 182 Variable containing:
# 1.00000e-02 *
#   4.7348
# [torch.FloatTensor of size 1]
#
# 183 Variable containing:
# 1.00000e-02 *
#   4.5489
# [torch.FloatTensor of size 1]
#
# 184 Variable containing:
# 1.00000e-02 *
#   4.3706
# [torch.FloatTensor of size 1]
#
# 185 Variable containing:
# 1.00000e-02 *
#   4.1997
# [torch.FloatTensor of size 1]
#
# 186 Variable containing:
# 1.00000e-02 *
#   4.0358
# [torch.FloatTensor of size 1]
#
# 187 Variable containing:
# 1.00000e-02 *
#   3.8788
# [torch.FloatTensor of size 1]
#
# 188 Variable containing:
# 1.00000e-02 *
#   3.7286
# [torch.FloatTensor of size 1]
#
# 189 Variable containing:
# 1.00000e-02 *
#   3.5846
# [torch.FloatTensor of size 1]
#
# 190 Variable containing:
# 1.00000e-02 *
#   3.4464
# [torch.FloatTensor of size 1]
#
# 191 Variable containing:
# 1.00000e-02 *
#   3.3139
# [torch.FloatTensor of size 1]
#
# 192 Variable containing:
# 1.00000e-02 *
#   3.1867
# [torch.FloatTensor of size 1]
#
# 193 Variable containing:
# 1.00000e-02 *
#   3.0649
# [torch.FloatTensor of size 1]
#
# 194 Variable containing:
# 1.00000e-02 *
#   2.9479
# [torch.FloatTensor of size 1]
#
# 195 Variable containing:
# 1.00000e-02 *
#   2.8355
# [torch.FloatTensor of size 1]
#
# 196 Variable containing:
# 1.00000e-02 *
#   2.7277
# [torch.FloatTensor of size 1]
#
# 197 Variable containing:
# 1.00000e-02 *
#   2.6242
# [torch.FloatTensor of size 1]
#
# 198 Variable containing:
# 1.00000e-02 *
#   2.5249
# [torch.FloatTensor of size 1]
#
# 199 Variable containing:
# 1.00000e-02 *
#   2.4295
# [torch.FloatTensor of size 1]
#
# 200 Variable containing:
# 1.00000e-02 *
#   2.3379
# [torch.FloatTensor of size 1]
#
# 201 Variable containing:
# 1.00000e-02 *
#   2.2499
# [torch.FloatTensor of size 1]
#
# 202 Variable containing:
# 1.00000e-02 *
#   2.1654
# [torch.FloatTensor of size 1]
#
# 203 Variable containing:
# 1.00000e-02 *
#   2.0843
# [torch.FloatTensor of size 1]
#
# 204 Variable containing:
# 1.00000e-02 *
#   2.0064
# [torch.FloatTensor of size 1]
#
# 205 Variable containing:
# 1.00000e-02 *
#   1.9316
# [torch.FloatTensor of size 1]
#
# 206 Variable containing:
# 1.00000e-02 *
#   1.8597
# [torch.FloatTensor of size 1]
#
# 207 Variable containing:
# 1.00000e-02 *
#   1.7906
# [torch.FloatTensor of size 1]
#
# 208 Variable containing:
# 1.00000e-02 *
#   1.7242
# [torch.FloatTensor of size 1]
#
# 209 Variable containing:
# 1.00000e-02 *
#   1.6603
# [torch.FloatTensor of size 1]
#
# 210 Variable containing:
# 1.00000e-02 *
#   1.5990
# [torch.FloatTensor of size 1]
#
# 211 Variable containing:
# 1.00000e-02 *
#   1.5401
# [torch.FloatTensor of size 1]
#
# 212 Variable containing:
# 1.00000e-02 *
#   1.4834
# [torch.FloatTensor of size 1]
#
# 213 Variable containing:
# 1.00000e-02 *
#   1.4289
# [torch.FloatTensor of size 1]
#
# 214 Variable containing:
# 1.00000e-02 *
#   1.3765
# [torch.FloatTensor of size 1]
#
# 215 Variable containing:
# 1.00000e-02 *
#   1.3261
# [torch.FloatTensor of size 1]
#
# 216 Variable containing:
# 1.00000e-02 *
#   1.2776
# [torch.FloatTensor of size 1]
#
# 217 Variable containing:
# 1.00000e-02 *
#   1.2310
# [torch.FloatTensor of size 1]
#
# 218 Variable containing:
# 1.00000e-02 *
#   1.1862
# [torch.FloatTensor of size 1]
#
# 219 Variable containing:
# 1.00000e-02 *
#   1.1430
# [torch.FloatTensor of size 1]
#
# 220 Variable containing:
# 1.00000e-02 *
#   1.1015
# [torch.FloatTensor of size 1]
#
# 221 Variable containing:
# 1.00000e-02 *
#   1.0615
# [torch.FloatTensor of size 1]
#
# 222 Variable containing:
# 1.00000e-02 *
#   1.0231
# [torch.FloatTensor of size 1]
#
# 223 Variable containing:
# 1.00000e-03 *
#   9.8608
# [torch.FloatTensor of size 1]
#
# 224 Variable containing:
# 1.00000e-03 *
#   9.5052
# [torch.FloatTensor of size 1]
#
# 225 Variable containing:
# 1.00000e-03 *
#   9.1627
# [torch.FloatTensor of size 1]
#
# 226 Variable containing:
# 1.00000e-03 *
#   8.8329
# [torch.FloatTensor of size 1]
#
# 227 Variable containing:
# 1.00000e-03 *
#   8.5160
# [torch.FloatTensor of size 1]
#
# 228 Variable containing:
# 1.00000e-03 *
#   8.2110
# [torch.FloatTensor of size 1]
#
# 229 Variable containing:
# 1.00000e-03 *
#   7.9171
# [torch.FloatTensor of size 1]
#
# 230 Variable containing:
# 1.00000e-03 *
#   7.6342
# [torch.FloatTensor of size 1]
#
# 231 Variable containing:
# 1.00000e-03 *
#   7.3620
# [torch.FloatTensor of size 1]
#
# 232 Variable containing:
# 1.00000e-03 *
#   7.0997
# [torch.FloatTensor of size 1]
#
# 233 Variable containing:
# 1.00000e-03 *
#   6.8470
# [torch.FloatTensor of size 1]
#
# 234 Variable containing:
# 1.00000e-03 *
#   6.6037
# [torch.FloatTensor of size 1]
#
# 235 Variable containing:
# 1.00000e-03 *
#   6.3695
# [torch.FloatTensor of size 1]
#
# 236 Variable containing:
# 1.00000e-03 *
#   6.1440
# [torch.FloatTensor of size 1]
#
# 237 Variable containing:
# 1.00000e-03 *
#   5.9268
# [torch.FloatTensor of size 1]
#
# 238 Variable containing:
# 1.00000e-03 *
#   5.7174
# [torch.FloatTensor of size 1]
#
# 239 Variable containing:
# 1.00000e-03 *
#   5.5158
# [torch.FloatTensor of size 1]
#
# 240 Variable containing:
# 1.00000e-03 *
#   5.3216
# [torch.FloatTensor of size 1]
#
# 241 Variable containing:
# 1.00000e-03 *
#   5.1345
# [torch.FloatTensor of size 1]
#
# 242 Variable containing:
# 1.00000e-03 *
#   4.9542
# [torch.FloatTensor of size 1]
#
# 243 Variable containing:
# 1.00000e-03 *
#   4.7804
# [torch.FloatTensor of size 1]
#
# 244 Variable containing:
# 1.00000e-03 *
#   4.6131
# [torch.FloatTensor of size 1]
#
# 245 Variable containing:
# 1.00000e-03 *
#   4.4517
# [torch.FloatTensor of size 1]
#
# 246 Variable containing:
# 1.00000e-03 *
#   4.2963
# [torch.FloatTensor of size 1]
#
# 247 Variable containing:
# 1.00000e-03 *
#   4.1464
# [torch.FloatTensor of size 1]
#
# 248 Variable containing:
# 1.00000e-03 *
#   4.0020
# [torch.FloatTensor of size 1]
#
# 249 Variable containing:
# 1.00000e-03 *
#   3.8629
# [torch.FloatTensor of size 1]
#
# 250 Variable containing:
# 1.00000e-03 *
#   3.7287
# [torch.FloatTensor of size 1]
#
# 251 Variable containing:
# 1.00000e-03 *
#   3.5993
# [torch.FloatTensor of size 1]
#
# 252 Variable containing:
# 1.00000e-03 *
#   3.4746
# [torch.FloatTensor of size 1]
#
# 253 Variable containing:
# 1.00000e-03 *
#   3.3543
# [torch.FloatTensor of size 1]
#
# 254 Variable containing:
# 1.00000e-03 *
#   3.2383
# [torch.FloatTensor of size 1]
#
# 255 Variable containing:
# 1.00000e-03 *
#   3.1265
# [torch.FloatTensor of size 1]
#
# 256 Variable containing:
# 1.00000e-03 *
#   3.0187
# [torch.FloatTensor of size 1]
#
# 257 Variable containing:
# 1.00000e-03 *
#   2.9147
# [torch.FloatTensor of size 1]
#
# 258 Variable containing:
# 1.00000e-03 *
#   2.8144
# [torch.FloatTensor of size 1]
#
# 259 Variable containing:
# 1.00000e-03 *
#   2.7177
# [torch.FloatTensor of size 1]
#
# 260 Variable containing:
# 1.00000e-03 *
#   2.6245
# [torch.FloatTensor of size 1]
#
# 261 Variable containing:
# 1.00000e-03 *
#   2.5345
# [torch.FloatTensor of size 1]
#
# 262 Variable containing:
# 1.00000e-03 *
#   2.4477
# [torch.FloatTensor of size 1]
#
# 263 Variable containing:
# 1.00000e-03 *
#   2.3640
# [torch.FloatTensor of size 1]
#
# 264 Variable containing:
# 1.00000e-03 *
#   2.2832
# [torch.FloatTensor of size 1]
#
# 265 Variable containing:
# 1.00000e-03 *
#   2.2053
# [torch.FloatTensor of size 1]
#
# 266 Variable containing:
# 1.00000e-03 *
#   2.1303
# [torch.FloatTensor of size 1]
#
# 267 Variable containing:
# 1.00000e-03 *
#   2.0578
# [torch.FloatTensor of size 1]
#
# 268 Variable containing:
# 1.00000e-03 *
#   1.9878
# [torch.FloatTensor of size 1]
#
# 269 Variable containing:
# 1.00000e-03 *
#   1.9203
# [torch.FloatTensor of size 1]
#
# 270 Variable containing:
# 1.00000e-03 *
#   1.8552
# [torch.FloatTensor of size 1]
#
# 271 Variable containing:
# 1.00000e-03 *
#   1.7924
# [torch.FloatTensor of size 1]
#
# 272 Variable containing:
# 1.00000e-03 *
#   1.7317
# [torch.FloatTensor of size 1]
#
# 273 Variable containing:
# 1.00000e-03 *
#   1.6731
# [torch.FloatTensor of size 1]
#
# 274 Variable containing:
# 1.00000e-03 *
#   1.6166
# [torch.FloatTensor of size 1]
#
# 275 Variable containing:
# 1.00000e-03 *
#   1.5620
# [torch.FloatTensor of size 1]
#
# 276 Variable containing:
# 1.00000e-03 *
#   1.5094
# [torch.FloatTensor of size 1]
#
# 277 Variable containing:
# 1.00000e-03 *
#   1.4586
# [torch.FloatTensor of size 1]
#
# 278 Variable containing:
# 1.00000e-03 *
#   1.4095
# [torch.FloatTensor of size 1]
#
# 279 Variable containing:
# 1.00000e-03 *
#   1.3621
# [torch.FloatTensor of size 1]
#
# 280 Variable containing:
# 1.00000e-03 *
#   1.3164
# [torch.FloatTensor of size 1]
#
# 281 Variable containing:
# 1.00000e-03 *
#   1.2722
# [torch.FloatTensor of size 1]
#
# 282 Variable containing:
# 1.00000e-03 *
#   1.2297
# [torch.FloatTensor of size 1]
#
# 283 Variable containing:
# 1.00000e-03 *
#   1.1885
# [torch.FloatTensor of size 1]
#
# 284 Variable containing:
# 1.00000e-03 *
#   1.1487
# [torch.FloatTensor of size 1]
#
# 285 Variable containing:
# 1.00000e-03 *
#   1.1103
# [torch.FloatTensor of size 1]
#
# 286 Variable containing:
# 1.00000e-03 *
#   1.0732
# [torch.FloatTensor of size 1]
#
# 287 Variable containing:
# 1.00000e-03 *
#   1.0374
# [torch.FloatTensor of size 1]
#
# 288 Variable containing:
# 1.00000e-03 *
#   1.0028
# [torch.FloatTensor of size 1]
#
# 289 Variable containing:
# 1.00000e-04 *
#   9.6943
# [torch.FloatTensor of size 1]
#
# 290 Variable containing:
# 1.00000e-04 *
#   9.3716
# [torch.FloatTensor of size 1]
#
# 291 Variable containing:
# 1.00000e-04 *
#   9.0601
# [torch.FloatTensor of size 1]
#
# 292 Variable containing:
# 1.00000e-04 *
#   8.7591
# [torch.FloatTensor of size 1]
#
# 293 Variable containing:
# 1.00000e-04 *
#   8.4681
# [torch.FloatTensor of size 1]
#
# 294 Variable containing:
# 1.00000e-04 *
#   8.1871
# [torch.FloatTensor of size 1]
#
# 295 Variable containing:
# 1.00000e-04 *
#   7.9158
# [torch.FloatTensor of size 1]
#
# 296 Variable containing:
# 1.00000e-04 *
#   7.6535
# [torch.FloatTensor of size 1]
#
# 297 Variable containing:
# 1.00000e-04 *
#   7.4002
# [torch.FloatTensor of size 1]
#
# 298 Variable containing:
# 1.00000e-04 *
#   7.1555
# [torch.FloatTensor of size 1]
#
# 299 Variable containing:
# 1.00000e-04 *
#   6.9189
# [torch.FloatTensor of size 1]
#
# 300 Variable containing:
# 1.00000e-04 *
#   6.6905
# [torch.FloatTensor of size 1]
#
# 301 Variable containing:
# 1.00000e-04 *
#   6.4697
# [torch.FloatTensor of size 1]
#
# 302 Variable containing:
# 1.00000e-04 *
#   6.2563
# [torch.FloatTensor of size 1]
#
# 303 Variable containing:
# 1.00000e-04 *
#   6.0501
# [torch.FloatTensor of size 1]
#
# 304 Variable containing:
# 1.00000e-04 *
#   5.8508
# [torch.FloatTensor of size 1]
#
# 305 Variable containing:
# 1.00000e-04 *
#   5.6581
# [torch.FloatTensor of size 1]
#
# 306 Variable containing:
# 1.00000e-04 *
#   5.4720
# [torch.FloatTensor of size 1]
#
# 307 Variable containing:
# 1.00000e-04 *
#   5.2922
# [torch.FloatTensor of size 1]
#
# 308 Variable containing:
# 1.00000e-04 *
#   5.1183
# [torch.FloatTensor of size 1]
#
# 309 Variable containing:
# 1.00000e-04 *
#   4.9504
# [torch.FloatTensor of size 1]
#
# 310 Variable containing:
# 1.00000e-04 *
#   4.7881
# [torch.FloatTensor of size 1]
#
# 311 Variable containing:
# 1.00000e-04 *
#   4.6311
# [torch.FloatTensor of size 1]
#
# 312 Variable containing:
# 1.00000e-04 *
#   4.4794
# [torch.FloatTensor of size 1]
#
# 313 Variable containing:
# 1.00000e-04 *
#   4.3326
# [torch.FloatTensor of size 1]
#
# 314 Variable containing:
# 1.00000e-04 *
#   4.1908
# [torch.FloatTensor of size 1]
#
# 315 Variable containing:
# 1.00000e-04 *
#   4.0538
# [torch.FloatTensor of size 1]
#
# 316 Variable containing:
# 1.00000e-04 *
#   3.9214
# [torch.FloatTensor of size 1]
#
# 317 Variable containing:
# 1.00000e-04 *
#   3.7934
# [torch.FloatTensor of size 1]
#
# 318 Variable containing:
# 1.00000e-04 *
#   3.6696
# [torch.FloatTensor of size 1]
#
# 319 Variable containing:
# 1.00000e-04 *
#   3.5498
# [torch.FloatTensor of size 1]
#
# 320 Variable containing:
# 1.00000e-04 *
#   3.4341
# [torch.FloatTensor of size 1]
#
# 321 Variable containing:
# 1.00000e-04 *
#   3.3222
# [torch.FloatTensor of size 1]
#
# 322 Variable containing:
# 1.00000e-04 *
#   3.2141
# [torch.FloatTensor of size 1]
#
# 323 Variable containing:
# 1.00000e-04 *
#   3.1094
# [torch.FloatTensor of size 1]
#
# 324 Variable containing:
# 1.00000e-04 *
#   3.0083
# [torch.FloatTensor of size 1]
# 325 Variable containing:
# 1.00000e-04 *
#   2.9106
# [torch.FloatTensor of size 1]
#
# 326 Variable containing:
# 1.00000e-04 *
#   2.8160
# [torch.FloatTensor of size 1]
#
# 327 Variable containing:
# 1.00000e-04 *
#   2.7247
# [torch.FloatTensor of size 1]
#
# 328 Variable containing:
# 1.00000e-04 *
#   2.6362
# [torch.FloatTensor of size 1]
#
# 329 Variable containing:
# 1.00000e-04 *
#   2.5507
# [torch.FloatTensor of size 1]
#
# 330 Variable containing:
# 1.00000e-04 *
#   2.4680
# [torch.FloatTensor of size 1]
#
# 331 Variable containing:
# 1.00000e-04 *
#   2.3881
# [torch.FloatTensor of size 1]
#
# 332 Variable containing:
# 1.00000e-04 *
#   2.3107
# [torch.FloatTensor of size 1]
#
# 333 Variable containing:
# 1.00000e-04 *
#   2.2359
# [torch.FloatTensor of size 1]
#
# 334 Variable containing:
# 1.00000e-04 *
#   2.1636
# [torch.FloatTensor of size 1]
#
# 335 Variable containing:
# 1.00000e-04 *
#   2.0936
# [torch.FloatTensor of size 1]
#
# 336 Variable containing:
# 1.00000e-04 *
#   2.0260
# [torch.FloatTensor of size 1]
#
# 337 Variable containing:
# 1.00000e-04 *
#   1.9606
# [torch.FloatTensor of size 1]
#
# 338 Variable containing:
# 1.00000e-04 *
#   1.8972
# [torch.FloatTensor of size 1]
#
# 339 Variable containing:
# 1.00000e-04 *
#   1.8360
# [torch.FloatTensor of size 1]
#
# 340 Variable containing:
# 1.00000e-04 *
#   1.7768
# [torch.FloatTensor of size 1]
#
# 341 Variable containing:
# 1.00000e-04 *
#   1.7195
# [torch.FloatTensor of size 1]
#
# 342 Variable containing:
# 1.00000e-04 *
#   1.6642
# [torch.FloatTensor of size 1]
#
# 343 Variable containing:
# 1.00000e-04 *
#   1.6106
# [torch.FloatTensor of size 1]
#
# 344 Variable containing:
# 1.00000e-04 *
#   1.5587
# [torch.FloatTensor of size 1]
#
# 345 Variable containing:
# 1.00000e-04 *
#   1.5085
# [torch.FloatTensor of size 1]
#
# 346 Variable containing:
# 1.00000e-04 *
#   1.4601
# [torch.FloatTensor of size 1]
#
# 347 Variable containing:
# 1.00000e-04 *
#   1.4131
# [torch.FloatTensor of size 1]
#
# 348 Variable containing:
# 1.00000e-04 *
#   1.3677
# [torch.FloatTensor of size 1]
#
# 349 Variable containing:
# 1.00000e-04 *
#   1.3237
# [torch.FloatTensor of size 1]
#
# 350 Variable containing:
# 1.00000e-04 *
#   1.2813
# [torch.FloatTensor of size 1]
#
# 351 Variable containing:
# 1.00000e-04 *
#   1.2402
# [torch.FloatTensor of size 1]
#
# 352 Variable containing:
# 1.00000e-04 *
#   1.2004
# [torch.FloatTensor of size 1]
#
# 353 Variable containing:
# 1.00000e-04 *
#   1.1619
# [torch.FloatTensor of size 1]
#
# 354 Variable containing:
# 1.00000e-04 *
#   1.1246
# [torch.FloatTensor of size 1]
#
# 355 Variable containing:
# 1.00000e-04 *
#   1.0886
# [torch.FloatTensor of size 1]
#
# 356 Variable containing:
# 1.00000e-04 *
#   1.0538
# [torch.FloatTensor of size 1]
#
# 357 Variable containing:
# 1.00000e-04 *
#   1.0200
# [torch.FloatTensor of size 1]
#
# 358 Variable containing:
# 1.00000e-05 *
#   9.8739
# [torch.FloatTensor of size 1]
#
# 359 Variable containing:
# 1.00000e-05 *
#   9.5578
# [torch.FloatTensor of size 1]
#
# 360 Variable containing:
# 1.00000e-05 *
#   9.2526
# [torch.FloatTensor of size 1]
#
# 361 Variable containing:
# 1.00000e-05 *
#   8.9569
# [torch.FloatTensor of size 1]
#
# 362 Variable containing:
# 1.00000e-05 *
#   8.6712
# [torch.FloatTensor of size 1]
#
# 363 Variable containing:
# 1.00000e-05 *
#   8.3942
# [torch.FloatTensor of size 1]
#
# 364 Variable containing:
# 1.00000e-05 *
#   8.1263
# [torch.FloatTensor of size 1]
#
# 365 Variable containing:
# 1.00000e-05 *
#   7.8668
# [torch.FloatTensor of size 1]
#
# 366 Variable containing:
# 1.00000e-05 *
#   7.6160
# [torch.FloatTensor of size 1]
#
# 367 Variable containing:
# 1.00000e-05 *
#   7.3732
# [torch.FloatTensor of size 1]
#
# 368 Variable containing:
# 1.00000e-05 *
#   7.1383
# [torch.FloatTensor of size 1]
#
# 369 Variable containing:
# 1.00000e-05 *
#   6.9113
# [torch.FloatTensor of size 1]
#
# 370 Variable containing:
# 1.00000e-05 *
#   6.6907
# [torch.FloatTensor of size 1]
#
# 371 Variable containing:
# 1.00000e-05 *
#   6.4778
# [torch.FloatTensor of size 1]
#
# 372 Variable containing:
# 1.00000e-05 *
#   6.2718
# [torch.FloatTensor of size 1]
#
# 373 Variable containing:
# 1.00000e-05 *
#   6.0723
# [torch.FloatTensor of size 1]
#
# 374 Variable containing:
# 1.00000e-05 *
#   5.8792
# [torch.FloatTensor of size 1]
#
# 375 Variable containing:
# 1.00000e-05 *
#   5.6925
# [torch.FloatTensor of size 1]
#
# 376 Variable containing:
# 1.00000e-05 *
#   5.5116
# [torch.FloatTensor of size 1]
#
# 377 Variable containing:
# 1.00000e-05 *
#   5.3364
# [torch.FloatTensor of size 1]
#
# 378 Variable containing:
# 1.00000e-05 *
#   5.1671
# [torch.FloatTensor of size 1]
#
# 379 Variable containing:
# 1.00000e-05 *
#   5.0033
# [torch.FloatTensor of size 1]
#
# 380 Variable containing:
# 1.00000e-05 *
#   4.8445
# [torch.FloatTensor of size 1]
#
# 381 Variable containing:
# 1.00000e-05 *
#   4.6909
# [torch.FloatTensor of size 1]
#
# 382 Variable containing:
# 1.00000e-05 *
#   4.5422
# [torch.FloatTensor of size 1]
#
# 383 Variable containing:
# 1.00000e-05 *
#   4.3979
# [torch.FloatTensor of size 1]
#
# 384 Variable containing:
# 1.00000e-05 *
#   4.2588
# [torch.FloatTensor of size 1]
#
# 385 Variable containing:
# 1.00000e-05 *
#   4.1238
# [torch.FloatTensor of size 1]
#
# 386 Variable containing:
# 1.00000e-05 *
#   3.9931
# [torch.FloatTensor of size 1]
#
# 387 Variable containing:
# 1.00000e-05 *
#   3.8666
# [torch.FloatTensor of size 1]
#
# 388 Variable containing:
# 1.00000e-05 *
#   3.7443
# [torch.FloatTensor of size 1]
#
# 389 Variable containing:
# 1.00000e-05 *
#   3.6259
# [torch.FloatTensor of size 1]
#
# 390 Variable containing:
# 1.00000e-05 *
#   3.5113
# [torch.FloatTensor of size 1]
#
# 391 Variable containing:
# 1.00000e-05 *
#   3.4003
# [torch.FloatTensor of size 1]
#
# 392 Variable containing:
# 1.00000e-05 *
#   3.2928
# [torch.FloatTensor of size 1]
#
# 393 Variable containing:
# 1.00000e-05 *
#   3.1888
# [torch.FloatTensor of size 1]
#
# 394 Variable containing:
# 1.00000e-05 *
#   3.0882
# [torch.FloatTensor of size 1]
#
# 395 Variable containing:
# 1.00000e-05 *
#   2.9906
# [torch.FloatTensor of size 1]
#
# 396 Variable containing:
# 1.00000e-05 *
#   2.8963
# [torch.FloatTensor of size 1]
#
# 397 Variable containing:
# 1.00000e-05 *
#   2.8049
# [torch.FloatTensor of size 1]
#
# 398 Variable containing:
# 1.00000e-05 *
#   2.7167
# [torch.FloatTensor of size 1]
#
# 399 Variable containing:
# 1.00000e-05 *
#   2.6306
# [torch.FloatTensor of size 1]
#
# 400 Variable containing:
# 1.00000e-05 *
#   2.5480
# [torch.FloatTensor of size 1]
#
# 401 Variable containing:
# 1.00000e-05 *
#   2.4676
# [torch.FloatTensor of size 1]
#
# 402 Variable containing:
# 1.00000e-05 *
#   2.3897
# [torch.FloatTensor of size 1]
#
# 403 Variable containing:
# 1.00000e-05 *
#   2.3145
# [torch.FloatTensor of size 1]
#
# 404 Variable containing:
# 1.00000e-05 *
#   2.2416
# [torch.FloatTensor of size 1]
#
# 405 Variable containing:
# 1.00000e-05 *
#   2.1712
# [torch.FloatTensor of size 1]
#
# 406 Variable containing:
# 1.00000e-05 *
#   2.1029
# [torch.FloatTensor of size 1]
#
# 407 Variable containing:
# 1.00000e-05 *
#   2.0367
# [torch.FloatTensor of size 1]
#
# 408 Variable containing:
# 1.00000e-05 *
#   1.9726
# [torch.FloatTensor of size 1]
#
# 409 Variable containing:
# 1.00000e-05 *
#   1.9105
# [torch.FloatTensor of size 1]
#
# 410 Variable containing:
# 1.00000e-05 *
#   1.8505
# [torch.FloatTensor of size 1]
#
# 411 Variable containing:
# 1.00000e-05 *
#   1.7924
# [torch.FloatTensor of size 1]
#
# 412 Variable containing:
# 1.00000e-05 *
#   1.7361
# [torch.FloatTensor of size 1]
#
# 413 Variable containing:
# 1.00000e-05 *
#   1.6815
# [torch.FloatTensor of size 1]
#
# 414 Variable containing:
# 1.00000e-05 *
#   1.6287
# [torch.FloatTensor of size 1]
#
# 415 Variable containing:
# 1.00000e-05 *
#   1.5778
# [torch.FloatTensor of size 1]
#
# 416 Variable containing:
# 1.00000e-05 *
#   1.5283
# [torch.FloatTensor of size 1]
#
# 417 Variable containing:
# 1.00000e-05 *
#   1.4802
# [torch.FloatTensor of size 1]
#
# 418 Variable containing:
# 1.00000e-05 *
#   1.4339
# [torch.FloatTensor of size 1]
#
# 419 Variable containing:
# 1.00000e-05 *
#   1.3889
# [torch.FloatTensor of size 1]
#
# 420 Variable containing:
# 1.00000e-05 *
#   1.3453
# [torch.FloatTensor of size 1]
#
# 421 Variable containing:
# 1.00000e-05 *
#   1.3031
# [torch.FloatTensor of size 1]
#
# 422 Variable containing:
# 1.00000e-05 *
#   1.2623
# [torch.FloatTensor of size 1]
#
# 423 Variable containing:
# 1.00000e-05 *
#   1.2229
# [torch.FloatTensor of size 1]
#
# 424 Variable containing:
# 1.00000e-05 *
#   1.1846
# [torch.FloatTensor of size 1]
#
# 425 Variable containing:
# 1.00000e-05 *
#   1.1475
# [torch.FloatTensor of size 1]
#
# 426 Variable containing:
# 1.00000e-05 *
#   1.1115
# [torch.FloatTensor of size 1]
#
# 427 Variable containing:
# 1.00000e-05 *
#   1.0767
# [torch.FloatTensor of size 1]
#
# 428 Variable containing:
# 1.00000e-05 *
#   1.0431
# [torch.FloatTensor of size 1]
#
# 429 Variable containing:
# 1.00000e-05 *
#   1.0105
# [torch.FloatTensor of size 1]
#
# 430 Variable containing:
# 1.00000e-06 *
#   9.7891
# [torch.FloatTensor of size 1]
#
# 431 Variable containing:
# 1.00000e-06 *
#   9.4826
# [torch.FloatTensor of size 1]
#
# 432 Variable containing:
# 1.00000e-06 *
#   9.1860
# [torch.FloatTensor of size 1]
#
# 433 Variable containing:
# 1.00000e-06 *
#   8.9000
# [torch.FloatTensor of size 1]
#
# 434 Variable containing:
# 1.00000e-06 *
#   8.6216
# [torch.FloatTensor of size 1]
#
# 435 Variable containing:
# 1.00000e-06 *
#   8.3519
# [torch.FloatTensor of size 1]
#
# 436 Variable containing:
# 1.00000e-06 *
#   8.0914
# [torch.FloatTensor of size 1]
#
# 437 Variable containing:
# 1.00000e-06 *
#   7.8389
# [torch.FloatTensor of size 1]
#
# 438 Variable containing:
# 1.00000e-06 *
#   7.5942
# [torch.FloatTensor of size 1]
#
# 439 Variable containing:
# 1.00000e-06 *
#   7.3566
# [torch.FloatTensor of size 1]
#
# 440 Variable containing:
# 1.00000e-06 *
#   7.1272
# [torch.FloatTensor of size 1]
#
# 441 Variable containing:
# 1.00000e-06 *
#   6.9064
# [torch.FloatTensor of size 1]
#
# 442 Variable containing:
# 1.00000e-06 *
#   6.6907
# [torch.FloatTensor of size 1]
#
# 443 Variable containing:
# 1.00000e-06 *
#   6.4815
# [torch.FloatTensor of size 1]
#
# 444 Variable containing:
# 1.00000e-06 *
#   6.2800
# [torch.FloatTensor of size 1]
#
# 445 Variable containing:
# 1.00000e-06 *
#   6.0837
# [torch.FloatTensor of size 1]
#
# 446 Variable containing:
# 1.00000e-06 *
#   5.8942
# [torch.FloatTensor of size 1]
#
# 447 Variable containing:
# 1.00000e-06 *
#   5.7113
# [torch.FloatTensor of size 1]
#
# 448 Variable containing:
# 1.00000e-06 *
#   5.5341
# [torch.FloatTensor of size 1]
#
# 449 Variable containing:
# 1.00000e-06 *
#   5.3620
# [torch.FloatTensor of size 1]
#
# 450 Variable containing:
# 1.00000e-06 *
#   5.1941
# [torch.FloatTensor of size 1]
#
# 451 Variable containing:
# 1.00000e-06 *
#   5.0334
# [torch.FloatTensor of size 1]
#
# 452 Variable containing:
# 1.00000e-06 *
#   4.8760
# [torch.FloatTensor of size 1]
#
# 453 Variable containing:
# 1.00000e-06 *
#   4.7247
# [torch.FloatTensor of size 1]
#
# 454 Variable containing:
# 1.00000e-06 *
#   4.5780
# [torch.FloatTensor of size 1]
#
# 455 Variable containing:
# 1.00000e-06 *
#   4.4355
# [torch.FloatTensor of size 1]
#
# 456 Variable containing:
# 1.00000e-06 *
#   4.2978
# [torch.FloatTensor of size 1]
#
# 457 Variable containing:
# 1.00000e-06 *
#   4.1643
# [torch.FloatTensor of size 1]
#
# 458 Variable containing:
# 1.00000e-06 *
#   4.0347
# [torch.FloatTensor of size 1]
#
# 459 Variable containing:
# 1.00000e-06 *
#   3.9099
# [torch.FloatTensor of size 1]
#
# 460 Variable containing:
# 1.00000e-06 *
#   3.7890
# [torch.FloatTensor of size 1]
#
# 461 Variable containing:
# 1.00000e-06 *
#   3.6710
# [torch.FloatTensor of size 1]
#
# 462 Variable containing:
# 1.00000e-06 *
#   3.5571
# [torch.FloatTensor of size 1]
#
# 463 Variable containing:
# 1.00000e-06 *
#   3.4465
# [torch.FloatTensor of size 1]
#
# 464 Variable containing:
# 1.00000e-06 *
#   3.3399
# [torch.FloatTensor of size 1]
#
# 465 Variable containing:
# 1.00000e-06 *
#   3.2368
# [torch.FloatTensor of size 1]
#
# 466 Variable containing:
# 1.00000e-06 *
#   3.1359
# [torch.FloatTensor of size 1]
#
# 467 Variable containing:
# 1.00000e-06 *
#   3.0386
# [torch.FloatTensor of size 1]
#
# 468 Variable containing:
# 1.00000e-06 *
#   2.9447
# [torch.FloatTensor of size 1]
#
# 469 Variable containing:
# 1.00000e-06 *
#   2.8531
# [torch.FloatTensor of size 1]
#
# 470 Variable containing:
# 1.00000e-06 *
#   2.7649
# [torch.FloatTensor of size 1]
#
# 471 Variable containing:
# 1.00000e-06 *
#   2.6795
# [torch.FloatTensor of size 1]
#
# 472 Variable containing:
# 1.00000e-06 *
#   2.5960
# [torch.FloatTensor of size 1]
#
# 473 Variable containing:
# 1.00000e-06 *
#   2.5158
# [torch.FloatTensor of size 1]
#
# 474 Variable containing:
# 1.00000e-06 *
#   2.4383
# [torch.FloatTensor of size 1]
#
# 475 Variable containing:
# 1.00000e-06 *
#   2.3627
# [torch.FloatTensor of size 1]
#
# 476 Variable containing:
# 1.00000e-06 *
#   2.2895
# [torch.FloatTensor of size 1]
#
# 477 Variable containing:
# 1.00000e-06 *
#   2.2188
# [torch.FloatTensor of size 1]
#
# 478 Variable containing:
# 1.00000e-06 *
#   2.1505
# [torch.FloatTensor of size 1]
#
# 479 Variable containing:
# 1.00000e-06 *
#   2.0836
# [torch.FloatTensor of size 1]
#
# 480 Variable containing:
# 1.00000e-06 *
#   2.0192
# [torch.FloatTensor of size 1]
#
# 481 Variable containing:
# 1.00000e-06 *
#   1.9567
# [torch.FloatTensor of size 1]
#
# 482 Variable containing:
# 1.00000e-06 *
#   1.8965
# [torch.FloatTensor of size 1]
#
# 483 Variable containing:
# 1.00000e-06 *
#   1.8376
# [torch.FloatTensor of size 1]
#
# 484 Variable containing:
# 1.00000e-06 *
#   1.7815
# [torch.FloatTensor of size 1]
#
# 485 Variable containing:
# 1.00000e-06 *
#   1.7258
# [torch.FloatTensor of size 1]
#
# 486 Variable containing:
# 1.00000e-06 *
#   1.6733
# [torch.FloatTensor of size 1]
#
# 487 Variable containing:
# 1.00000e-06 *
#   1.6214
# [torch.FloatTensor of size 1]
#
# 488 Variable containing:
# 1.00000e-06 *
#   1.5712
# [torch.FloatTensor of size 1]
#
# 489 Variable containing:
# 1.00000e-06 *
#   1.5226
# [torch.FloatTensor of size 1]
#
# 490 Variable containing:
# 1.00000e-06 *
#   1.4759
# [torch.FloatTensor of size 1]
#
# 491 Variable containing:
# 1.00000e-06 *
#   1.4302
# [torch.FloatTensor of size 1]
#
# 492 Variable containing:
# 1.00000e-06 *
#   1.3860
# [torch.FloatTensor of size 1]
#
# 493 Variable containing:
# 1.00000e-06 *
#   1.3433
# [torch.FloatTensor of size 1]
#
# 494 Variable containing:
# 1.00000e-06 *
#   1.3019
# [torch.FloatTensor of size 1]
#
# 495 Variable containing:
# 1.00000e-06 *
#   1.2616
# [torch.FloatTensor of size 1]
#
# 496 Variable containing:
# 1.00000e-06 *
#   1.2227
# [torch.FloatTensor of size 1]
#
# 497 Variable containing:
# 1.00000e-06 *
#   1.1851
# [torch.FloatTensor of size 1]
#
# 498 Variable containing:
# 1.00000e-06 *
#   1.1486
# [torch.FloatTensor of size 1]
#
# 499 Variable containing:
# 1.00000e-06 *
#   1.1137
# [torch.FloatTensor of size 1]
